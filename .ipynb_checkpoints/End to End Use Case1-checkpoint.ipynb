# %% [markdown]
# # End to End ML Project

# %% [markdown]
# ### Steps for ML Project
# 1. Import libraries
# 2. Data Cleaning
# 3. EDA
# 4. Data Preprocessing
# 5. Model Fitting
# 6. Model Evaluation
# 7. Model Optimization
# 8. Model Interpretation
# 9. Model Deployment

# %%
# !pip install imbalanced-learn
# Out:
# Collecting imbalanced-learn
#   Using cached imbalanced_learn-0.10.0-py3-none-any.whl (225 kB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from imbalanced-learn) (2.2.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from imbalanced-learn) (1.1.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from imbalanced-learn) (1.21.5)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from imbalanced-learn) (1.1.3)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from imbalanced-learn) (1.9.3)
# Installing collected packages: imbalanced-learn
# Successfully installed imbalanced-learn-0.10.0

# %%
# !pip install shap
# Out:
# Collecting shap
#   Downloading shap-0.41.0-cp38-cp38-win_amd64.whl (435 kB)
#      ------------------------------------ 435.6/435.6 kB 632.9 kB/s eta 0:00:00
# Requirement already satisfied: scipy in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from shap) (1.9.3)
# Requirement already satisfied: packaging>20.9 in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from shap) (21.3)
# Collecting slicer==0.0.7
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: numba in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from shap) (0.56.4)
# Requirement already satisfied: cloudpickle in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from shap) (2.0.0)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from shap) (1.21.5)
# Requirement already satisfied: pandas in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from shap) (1.5.2)
# Requirement already satisfied: tqdm>4.25.0 in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from shap) (4.64.1)
# Requirement already satisfied: scikit-learn in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from shap) (1.1.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from packaging>20.9->shap) (3.0.9)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from tqdm>4.25.0->shap) (0.4.5)
# Requirement already satisfied: setuptools in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from numba->shap) (65.5.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from numba->shap) (0.39.1)
# Requirement already satisfied: importlib-metadata in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from numba->shap) (4.11.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from pandas->shap) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from scikit-learn->shap) (2.2.0)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from scikit-learn->shap) (1.1.1)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from python-dateutil>=2.8.1->pandas->shap) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from importlib-metadata->numba->shap) (3.8.0)
# Installing collected packages: slicer, shap
# Successfully installed shap-0.41.0 slicer-0.0.7

# %%
# !pip install --pre pycaret
# Out:
# ^C

# %%
# !pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.16.0-py2.py3-none-any.whl (9.2 MB)
#      ---------------------------------------- 9.2/9.2 MB 807.6 kB/s eta 0:00:00
# Collecting pydeck>=0.1.dev5
#   Downloading pydeck-0.8.0-py2.py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 770.0 kB/s eta 0:00:00
# Collecting protobuf<4,>=3.12
#   Downloading protobuf-3.20.3-cp38-cp38-win_amd64.whl (904 kB)
#      ------------------------------------ 904.4/904.4 kB 818.1 kB/s eta 0:00:00
# Collecting validators>=0.2
#   Downloading validators-0.20.0.tar.gz (30 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from streamlit) (4.11.3)
# Collecting tzlocal>=1.1
#   Downloading tzlocal-4.2-py3-none-any.whl (19 kB)
# Collecting pyarrow>=4.0
#   Downloading pyarrow-10.0.1-cp38-cp38-win_amd64.whl (20.3 MB)
#      ---------------------------------------- 20.3/20.3 MB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.4 in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from streamlit) (2.28.1)
# Requirement already satisfied: click>=7.0 in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from streamlit) (8.0.4)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from streamlit) (1.21.5)
# Requirement already satisfied: pandas>=0.21.0 in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from streamlit) (1.5.2)
# Requirement already satisfied: packaging>=14.1 in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from streamlit) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from streamlit) (9.2.0)
# Requirement already satisfied: tornado>=5.0 in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from streamlit) (6.1)
# Collecting blinker>=1.0.0
#   Downloading blinker-1.5-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: python-dateutil in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from streamlit) (2.8.2)
# Collecting rich>=10.11.0
#   Downloading rich-12.6.0-py3-none-any.whl (237 kB)
#      ------------------------------------ 237.5/237.5 kB 454.5 kB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.10.0.0 in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from streamlit) (4.4.0)
# Requirement already satisfied: toml in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from streamlit) (0.10.2)
# Collecting gitpython!=3.1.19
#   Downloading GitPython-3.1.29-py3-none-any.whl (182 kB)
#      ------------------------------------ 182.5/182.5 kB 613.0 kB/s eta 0:00:00
# Collecting altair>=3.2.0
#   Downloading altair-4.2.0-py3-none-any.whl (812 kB)
#      -------------------------------------- 812.8/812.8 kB 1.1 MB/s eta 0:00:00
# Collecting cachetools>=4.0
#   Downloading cachetools-5.2.0-py3-none-any.whl (9.3 kB)
# Collecting pympler>=0.9
#   Downloading Pympler-1.0.1-py3-none-any.whl (164 kB)
#      ------------------------------------ 164.8/164.8 kB 898.7 kB/s eta 0:00:00
# Requirement already satisfied: watchdog in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from streamlit) (2.1.6)
# Collecting semver
#   Downloading semver-2.13.0-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from altair>=3.2.0->streamlit) (4.16.0)
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from altair>=3.2.0->streamlit) (3.1.2)
# Requirement already satisfied: entrypoints in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from altair>=3.2.0->streamlit) (0.4)
# Requirement already satisfied: toolz in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from altair>=3.2.0->streamlit) (0.12.0)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from click>=7.0->streamlit) (0.4.5)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ---------------------------------------- 62.7/62.7 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from importlib-metadata>=1.4->streamlit) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from packaging>=14.1->streamlit) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from pandas>=0.21.0->streamlit) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from python-dateutil->streamlit) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from requests>=2.4->streamlit) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from requests>=2.4->streamlit) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from requests>=2.4->streamlit) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from requests>=2.4->streamlit) (2022.9.24)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from rich>=10.11.0->streamlit) (2.11.2)
# Collecting commonmark<0.10.0,>=0.9.0
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
#      ---------------------------------------- 51.1/51.1 kB 1.3 MB/s eta 0:00:00
# Collecting backports.zoneinfo
#   Downloading backports.zoneinfo-0.2.1-cp38-cp38-win_amd64.whl (38 kB)
# Collecting pytz-deprecation-shim
#   Downloading pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl (15 kB)
# Collecting tzdata
#   Downloading tzdata-2022.7-py2.py3-none-any.whl (340 kB)
#      -------------------------------------- 340.1/340.1 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: decorator>=3.4.0 in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from validators>=0.2->streamlit) (5.1.1)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from jinja2->altair>=3.2.0->streamlit) (2.1.1)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (1.3.10)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (0.18.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (5.2.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (22.1.0)
# Building wheels for collected packages: validators
#   Building wheel for validators (setup.py): started
#   Building wheel for validators (setup.py): finished with status 'done'
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19579 sha256=946908b6db2edaf0970cb7a436a4acd43faa23e627fa95bd65f2a314e9e8ae61
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\cb\aa\fe\3316d4394e9ad09ea76561bd5be33f6d01828ff125ab2a3395
# Successfully built validators
# Installing collected packages: commonmark, validators, tzdata, smmap, semver, rich, pympler, pyarrow, protobuf, cachetools, blinker, backports.zoneinfo, pytz-deprecation-shim, pydeck, gitdb, tzlocal, gitpython, altair, streamlit
# Successfully installed altair-4.2.0 backports.zoneinfo-0.2.1 blinker-1.5 cachetools-5.2.0 commonmark-0.9.1 gitdb-4.0.10 gitpython-3.1.29 protobuf-3.20.3 pyarrow-10.0.1 pydeck-0.8.0 pympler-1.0.1 pytz-deprecation-shim-0.1.0.post0 rich-12.6.0 semver-2.13.0 smmap-5.0.0 streamlit-1.16.0 tzdata-2022.7 tzlocal-4.2 validators-0.20.0

# %%
# !pip install imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (0.10.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from imbalanced-learn) (1.1.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from imbalanced-learn) (1.21.5)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from imbalanced-learn) (1.1.3)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from imbalanced-learn) (1.9.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from imbalanced-learn) (2.2.0)

# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-1.7.2-py3-none-win_amd64.whl (89.1 MB)
#      -------------------------------------- 89.1/89.1 MB 340.3 kB/s eta 0:00:00
# Requirement already satisfied: scipy in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from xgboost) (1.9.3)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\envs\mldemo\envs\demo2\lib\site-packages (from xgboost) (1.21.5)
# Installing collected packages: xgboost
# Successfully installed xgboost-1.7.2

# %% [markdown]
# ### Import Libraries

# %%
# for data manipulation 
import pandas as pd
import numpy as np

# for EDA
import matplotlib.pyplot as plt
import seaborn as sns 
plt.figure(figsize=(12,7))
plt.style.use("fivethirtyeight")
# for Data preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV, train_test_split

# for Modelling
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier

# for Model evaluation
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report 

# for model optimization and interpretation
from sklearn.model_selection import train_test_split
import shap

# for warnings
import warnings
warnings.filterwarnings("ignore")
print("All libraries are imported")
# Out:
# All libraries are imported

# %%
# get the data 
data=pd.read_csv("data.csv")

# %%
# view the data 
data.head()
# Out:
#    Unnamed: 0  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0           0            6      148             72             35        0
# 1           1            1       85             66             29        0
# 2           2            8      183             64              0        0
# 3           3            1       89             66             23       94
# 4           4            0      137             40             35      168
#
#     BMI  DiabetesPedigreeFunction  Age Outcome
# 0  33.6                     0.627   50     Yes
# 1  26.6                     0.351   31      No
# 2  23.3                     0.672   32     Yes
# 3  28.1                     0.167   21      No
# 4  43.1                     2.288   33     Yes

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                768 non-null    int64
#  1   Pregnancies               768 non-null    int64
#  2   Glucose                   768 non-null    int64
#  3   BloodPressure             768 non-null    int64
#  4   SkinThickness             768 non-null    int64
#  5   Insulin                   768 non-null    int64
#  6   BMI                       768 non-null    float64
#  7   DiabetesPedigreeFunction  768 non-null    float64
#  8   Age                       768 non-null    int64
#  9   Outcome                   768 non-null    object
# dtypes: float64(2), int64(7), object(1)
# memory usage: 60.1+ KB

# %%
#check for null
data.isnull().sum()
# Out:
# Unnamed: 0                  0
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
# check for zero errors 
data.describe().T
# Out:
#                           count        mean         std     min        25%  \
# Unnamed: 0                768.0  383.500000  221.846794   0.000  191.75000
# Pregnancies               768.0    3.845052    3.369578   0.000    1.00000
# Glucose                   768.0  120.894531   31.972618   0.000   99.00000
# BloodPressure             768.0   69.105469   19.355807   0.000   62.00000
# SkinThickness             768.0   20.536458   15.952218   0.000    0.00000
# Insulin                   768.0   79.799479  115.244002   0.000    0.00000
# BMI                       768.0   31.992578    7.884160   0.000   27.30000
# DiabetesPedigreeFunction  768.0    0.471876    0.331329   0.078    0.24375
# Age                       768.0   33.240885   11.760232  21.000   24.00000
#
#                                50%        75%     max
# Unnamed: 0                383.5000  575.25000  767.00
# Pregnancies                 3.0000    6.00000   17.00
# Glucose                   117.0000  140.25000  199.00
# BloodPressure              72.0000   80.00000  122.00
# SkinThickness              23.0000   32.00000   99.00
# Insulin                    30.5000  127.25000  846.00
# BMI                        32.0000   36.60000   67.10
# DiabetesPedigreeFunction    0.3725    0.62625    2.42
# Age                        29.0000   41.00000   81.00

# %%
# check for duplicates 
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Observations**
# 1. The data has 768 rows and 10 columns
# 2. Column Unnamed: 0 is a reducndnat column and will be dropped
# 3. Columns Pregnancies, Glucose, BloodPressure, SkinThickness , Insulin and BMI have 0 errors and has to be impyuted with column medians
# 4. There are no missing values
# 5. Only outcome is categorical and it has to encoded before modelling
# 6. There are no duplicates

# %%
# drop the Unnamed column 
data.drop("Unnamed: 0", axis=1, inplace=True)

# %%
# impute zero errors
zerofiller=lambda x: x.replace(0, x.median())
cols=data.columns[1:6]
data[cols]=data[cols].apply(zerofiller, axis=0)

# %%
# check descriptives again
data.describe().T
# Out:
#                           count        mean         std     min       25%  \
# Pregnancies               768.0    3.845052    3.369578   0.000   1.00000
# Glucose                   768.0  121.656250   30.438286  44.000  99.75000
# BloodPressure             768.0   72.386719   12.096642  24.000  64.00000
# SkinThickness             768.0   27.334635    9.229014   7.000  23.00000
# Insulin                   768.0   94.652344  105.547598  14.000  30.50000
# BMI                       768.0   32.450911    6.875366  18.200  27.50000
# DiabetesPedigreeFunction  768.0    0.471876    0.331329   0.078   0.24375
# Age                       768.0   33.240885   11.760232  21.000  24.00000
#
#                                50%        75%     max
# Pregnancies                 3.0000    6.00000   17.00
# Glucose                   117.0000  140.25000  199.00
# BloodPressure              72.0000   80.00000  122.00
# SkinThickness              23.0000   32.00000   99.00
# Insulin                    31.2500  127.25000  846.00
# BMI                        32.0000   36.60000   67.10
# DiabetesPedigreeFunction    0.3725    0.62625    2.42
# Age                        29.0000   41.00000   81.00

# %% [markdown]
# Data looks good for EDA

# %% [markdown]
# ### Exploratory Data Analysis(EDA)
# - Univariate Analysis
#          -- numerical - histplots and boxplots
#          -- categorical
# - Bivariate Analysis
#          -- categorical vs numerical
#          -- numerical vs numerical
# - Multivariate
#          -- pairplots
# - Correlations
#          -- heatmaps

# %%
# Lets do Univariate Histograms 
def histograms(data):
    data.hist()
    plt.tight_layout()
    plt.show()

# %%
histograms(data)

# %%
# Lets do side by side histplot adn boxplots 
def histplot_boxplot(data, feature, figsize=(12,7), bins=None):
    fig, (ax_box, ax_hist)=plt.subplots(
    nrows=2,
    sharex=True,
    gridspec_kw={"height_ratios":(0.25, 0.75)},
    figsize=figsize )
    
    sns.boxplot(data=data, x=feature, showmeans=True, color="violet", ax=ax_box)
    sns.histplot(data=data, x=feature,pallete="winter", bins=bins, ax=ax_hist) if bins else sns.histplot(data=data,
                                                                     x=feature, ax=ax_hist)
    ax_hist.axvline(data[feature].mean(), linestyle="--", color="green")
    ax_hist.axvline(data[feature].median(), linestyle="-", color="black")
    plt.show()

# %%
for col in data.select_dtypes(exclude="O").columns:
    print(col)
    histplot_boxplot(data=data, feature=col)
    plt.show()
# Out:
# Pregnancies
# Glucose
# BloodPressure
# SkinThickness
# Insulin
# BMI
# DiabetesPedigreeFunction
# Age

# %% [markdown]
# Observations
# 1. Outliers- Preganancies, SkinThickness, Insulin , Diabetes Pedigree Function have lots of outliers we may need to cap the outer limit
# 2. Skew- SkinThickness, Insulin , Diabetes Pedigree Function are highly right skewed and needs to be transformed using log or square root

# %%
# univariate Countplot
def countplot(data, feature):
    plt.figure(figsize=(12,7))
    ax=sns.countplot(data=data, x=feature, color="green")
    for p in ax.patches:
        x=p.get_bbox().get_points()[:,0]
        y=p.get_bbox().get_points()[1,1]
        ax.annotate("{:.3g}%".format(100.*y/len(data)), (x.mean(), y), ha="center", va="bottom")
    plt.show()

# %%
countplot(data=data,feature="Outcome")

# %% [markdown]
# The Outcome variable is not balanced. We would need for solve for data imbaalnce before modelling

# %%
# Bivariate -categorical vs numerical
def bivariate_barplot(data, feature1, feature2):
    data.groupby(feature1)[feature2].mean().plot(kind="bar", color="orange")
    plt.ylabel(col)
    plt.show()

# %%
for col in data.select_dtypes(exclude="O").columns:
    print("Outcome vs ", col)
    bivariate_barplot(data=data, feature1="Outcome",feature2= col)
    print("**************************************")
# Out:
# Outcome vs  Pregnancies
# **************************************
# Outcome vs  Glucose
# **************************************
# Outcome vs  BloodPressure
# **************************************
# Outcome vs  SkinThickness
# **************************************
# Outcome vs  Insulin
# **************************************
# Outcome vs  BMI
# **************************************
# Outcome vs  DiabetesPedigreeFunction
# **************************************
# Outcome vs  Age
# **************************************

# %% [markdown]
# Those with higher Pregnancies, Glucose, Insulin, BMI and Age are more likely to be diabetic

# %%
# numericall vs numerical
def lineplot_scatterplot(data, feature1, feature2):
    plt.figure(figsize=(16,7))
    plt.subplot(1,2,1)
    sns.lineplot(data=data, x=feature1, y=feature2, color="green")
    plt.title("Lineplotbetween {0} and {1}".format(feature1, feature2))
    
    plt.subplot(1,2,2)
    sns.scatterplot(data=data, x=feature1, y=feature2, color="orange", hue="Outcome")
    plt.title("Scatter Plot Between {0} and {1}".format(feature1, feature2))
    plt.show()

# %%
for col in data.select_dtypes(exclude="O").columns:
    lineplot_scatterplot(data=data, feature1="Age", feature2=col)

# %%
# create acorrelation matrix
data.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.128213       0.208615       0.032568
# Glucose                      0.128213  1.000000       0.218937       0.172143
# BloodPressure                0.208615  0.218937       1.000000       0.147809
# SkinThickness                0.032568  0.172143       0.147809       1.000000
# Insulin                     -0.055697  0.357573      -0.028721       0.238188
# BMI                          0.021546  0.231400       0.281132       0.546951
# DiabetesPedigreeFunction    -0.033523  0.137327      -0.002378       0.142977
# Age                          0.544341  0.266909       0.324915       0.054514
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.055697  0.021546                 -0.033523
# Glucose                   0.357573  0.231400                  0.137327
# BloodPressure            -0.028721  0.281132                 -0.002378
# SkinThickness             0.238188  0.546951                  0.142977
# Insulin                   1.000000  0.189022                  0.178029
# BMI                       0.189022  1.000000                  0.153506
# DiabetesPedigreeFunction  0.178029  0.153506                  1.000000
# Age                      -0.015413  0.025744                  0.033561
#
#                                Age
# Pregnancies               0.544341
# Glucose                   0.266909
# BloodPressure             0.324915
# SkinThickness             0.054514
# Insulin                  -0.015413
# BMI                       0.025744
# DiabetesPedigreeFunction  0.033561
# Age                       1.000000

# %%
df=data.copy()
d={"Yes":1, "No":0}
df["Outcome"]=df["Outcome"].map(d)

# %%
df[df.columns[:]].corr()["Outcome"]
# Out:
# Pregnancies                 0.221898
# Glucose                     0.492782
# BloodPressure               0.165723
# SkinThickness               0.189065
# Insulin                     0.148457
# BMI                         0.312249
# DiabetesPedigreeFunction    0.173844
# Age                         0.238356
# Outcome                     1.000000
# Name: Outcome, dtype: float64

# %%
sns.pairplot(df, hue="Outcome", kind='reg')

# %%
plt.figure(figsize=(12,7))
sns.heatmap(df.corr(), annot=True, cmap="viridis")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # processing

# %%
X=df.drop('Outcome',axis=1)
y=df.Outcome

# %%
y.value_counts(normalize=True)
# Out:
# 0    0.651042
# 1    0.348958
# Name: Outcome, dtype: float64

# %%
# balancing the data
from imblearn.over_sampling import SMOTE
sm=SMOTE()
X,y=sm.fit_resample(X,y)

# %%
y.value_counts(normalize=True)
# Out:
# 1    0.5
# 0    0.5
# Name: Outcome, dtype: float64

# %%
# Spliting the data
xtrain,xtest,ytrain,ytest=train_test_split(X,y,test_size=0.3,random_state=42,stratify=y)

# %%
# scaling the data
sc=StandardScaler()
xtrain=sc.fit_transform(xtrain)
xtest=sc.transform(xtest)

# %%
xtrain.shape,xtest.shape,ytrain.shape, ytest.shape
# Out:
# ((700, 8), (300, 8), (700,), (300,))

# %% [markdown]
# ## Model Fitting , Evaluation , Optimization , interpretation

# %%
# Create a metric fn
def print_metrics(ytest,ypred,model_name):
    print('Metrics of the model : ',model_name)
    print()
    print('Accuracy score is {:.3f}'.format(accuracy_score(ytest,ypred)))
    print('Recall score is {:.3f}'.format(recall_score(ytest,ypred)))    
    print('Precision score is {:.3f}'.format(precision_score(ytest,ypred)))    
    print('F1 score is {:.3f}'.format(f1_score(ytest,ypred)))    
    print('Roc Auc score is {:.3f}'.format(roc_auc_score(ytest,ypred))) 
    print('Classification Report\n ',classification_report(ytest,ypred))

# %%
def plot_metrics(clf,xtest,ytest):
    plot_confusion_matrix(clf,xtest,ytest,display_labels=[0,1])
    print()
    plot_roc_auc_curve(clf,xtest,ytest)
    print()
    plot_precison_recall_curve(clf,xtest,ytest)
    plt.show()

# %% [markdown]
# ### fit and evaluate a knn  model

# %%
knn=KNeighborsClassifier()
knn.fit(xtrain,ytrain)
ypred=knn.predict(xtest)
print_metrics(ytest,ypred,knn)
# Out:
# Metrics of the model :  KNeighborsClassifier()
#
# Accuracy score is 0.773
# Recall score is 0.800
# Precision score is 0.759
# F1 score is 0.779
# Roc Auc score is 0.773
# Classification Report
#                 precision    recall  f1-score   support
#
#            0       0.79      0.75      0.77       150
#            1       0.76      0.80      0.78       150
#
#     accuracy                           0.77       300
#    macro avg       0.77      0.77      0.77       300
# weighted avg       0.77      0.77      0.77       300

# %%
#n
neighbors = range(1,25,1)
train = np.empty(len(neighbors))
test = np.empty(len(neighbors))

for i, k in enumerate(neighbors):
    knn = Kneighbors
